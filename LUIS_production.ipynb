# %% [markdown]
# # LUIS production

# %% [markdown]
# Nous allons dans ce notebook entrainer notre modèle avec toutes les données d'entrainement. Et nous utiliserons les données de test pour le test.
#
# Nous allons reproduire une partie du notebook "LUIS" où nous avons effectué un premier essai de création d'application et d'entrainement via un seul exemple.
#
# Commençons avec la création de l'application.

# %% [markdown]
# # Import des librairies

# %%
import json, time, uuid
import re

import os
from dotenv import load_dotenv

import pandas as pd
import numpy as np
from tqdm import tqdm

from dateutil.parser import parse
from price_parser import Price

from azure.cognitiveservices.language.luis.authoring import LUISAuthoringClient
from azure.cognitiveservices.language.luis.authoring.models import ApplicationCreateObject
from azure.cognitiveservices.language.luis.runtime import LUISRuntimeClient
from msrest.authentication import CognitiveServicesCredentials
from functools import reduce

# %%
authoringKey = os.environ.get("APP_AUTHORING_KEY")
authoringEndpoint = os.environ.get("ENDPOINT_AUTHORING_URL")
predictionKey = os.environ.get("APP_PREDICTION_KEY")
predictionEndpoint = os.environ.get("ENDPOINT_PREDICTION_URL")

appName = 'LUIS-P10'
versionId = "0.1"
intentName = "Booking"

# %%
client = LUISAuthoringClient(authoringEndpoint,
                             CognitiveServicesCredentials(authoringKey))

# %%
# define app basics
appDefinition = ApplicationCreateObject(name=appName,
                                        initial_version_id=versionId,
                                        culture='en-us')

# create app
app_id = client.apps.add(appDefinition)

# get app id - necessary for all other changes
print("Created LUIS app with ID {}".format(app_id))
# Out:
# Created LUIS app with ID 0fa21d7f-f2fb-4cd2-9835-25ddd194251d

# %%
# app_id = "e1365658-152c-43ef-b0b3-6d443ad954a9"

client.model.add_intent(app_id, versionId, intentName)
# Out:
# 'df5415ec-224a-45f4-bad1-478a9c9785f3'

# %%
def get_grandchild_id(model, childName, grandChildName):

    theseChildren = next(
        filter((lambda child: child.name == childName), model.children))
    theseGrandchildren = next(
        filter((lambda child: child.name == grandChildName),
               theseChildren.children))

    grandChildId = theseGrandchildren.id

    return grandChildId

# %%
# Add Prebuilt entity
client.model.add_prebuilt(
    app_id,
    versionId,
    prebuilt_extractor_names=['datetimeV2', 'money', 'geographyV2'])

# define machine-learned entity
mlEntityDefinition = [{
    "name":
    "Fly",
    "children": [{
        "name": "or_city"
    }, {
        "name": "dst_city"
    }, {
        "name": "str_date"
    }, {
        "name": "end_date"
    }, {
        "name": "budget"
    }]
}]

# add entity to app
modelId = client.model.add_entity(app_id,
                                  versionId,
                                  name="FlyOrder",
                                  children=mlEntityDefinition)

# define phraselist - add phrases as significant vocabulary to app
# Ajoute un poids aux mots
phraseList2 = {
    "enabledForAllModels": False,
    "isExchangeable": True,
    "name": "Phraselist",
    "phrases": "fly, destination, hotel"
}

# add phrase list to app
phraseListId2 = client.features.add_phrase_list(app_id, versionId, phraseList2)

# add phrase list as feature to subentity model
modelObject = client.model.get_entity(app_id, versionId, modelId)
FlyDst_cityId = get_grandchild_id(modelObject, "Fly", "dst_city")

phraseListFeatureDefinition = {
    "feature_name": "Phraselist",
    "model_name": None
}
client.features.add_entity_feature(app_id, versionId, FlyDst_cityId,
                                   phraseListFeatureDefinition)

# %%
# Define labeled example
labeledExampleUtteranceWithMLEntity = {
    "text":
    'IM IN TIJUANA FIND ME A FLIGHT TO CURITIBA AUG 27 TO SEPT 4 for a budget of 3500 dollars',
    "intentName":
    intentName,
    "entityLabels": [{
        "startCharIndex":
        6,
        "endCharIndex":
        87,
        "entityName":
        "FlyOrder",
        "children": [{
            "startCharIndex":
            6,
            "endCharIndex":
            87,
            "entityName":
            "Fly",
            "children": [{
                "startCharIndex": 6,
                "endCharIndex": 13,
                "entityName": "or_city"
            }, {
                "startCharIndex": 34,
                "endCharIndex": 42,
                "entityName": "dst_city"
            }, {
                "startCharIndex": 43,
                "endCharIndex": 49,
                "entityName": "str_date"
            }, {
                "startCharIndex": 53,
                "endCharIndex": 59,
                "entityName": "end_date"
            }, {
                "startCharIndex": 76,
                "endCharIndex": 87,
                "entityName": "budget"
            }]
        }]
    }]
}

client.examples.add(app_id, versionId, labeledExampleUtteranceWithMLEntity,
                    {"enableNestedChildren": True})

# %% [markdown]
# Tout fonctionne correctement, notre application est maintenant créée, nous allons à présent l'entrainer avec toutes les données d'entrainement.

# %% [markdown]
# # Entrainement

# %% [markdown]
# Importons nos JSON et essayons d'entrainer notre modèle.

# %%
f = open('data/train.json')
train = json.load(f)

f = open('data/test.json')
test = json.load(f)

f = open('data/val.json')
val = json.load(f)

# %% [markdown]
# ## Envoie des utterances

# %%
# %%time
for i in train:
    client.examples.add(app_id, versionId, i, {"enableNestedChildren": True})
# Out:
# 300
# 600
# 900
# CPU times: total: 4.92 s
# Wall time: 5min 15s

# %% [markdown]
# ## Entrainement du modèle

# %%
client.train.train_version(app_id, versionId)
waiting = True
while waiting:
    info = client.train.get_status(app_id, versionId)

    # get_status returns a list of training statuses, one for each model. Loop through them and make sure all are done.
    waiting = any(
        map(
            lambda x: 'Queued' == x.details.status or 'InProgress' == x.details
            .status, info))
    if waiting:
        print("Waiting 10 seconds for training to complete...")
        time.sleep(10)
    else:
        print("trained")
        waiting = False
# Out:
# Waiting 10 seconds for training to complete...
# Waiting 10 seconds for training to complete...
# trained

# %% [markdown]
# ## Publication du modèle

# %%
# Mark the app as public so we can query it using any prediction endpoint.
# Note: For production scenarios, you should instead assign the app to your own LUIS prediction endpoint. See:
# https://docs.microsoft.com/en-gb/azure/cognitive-services/luis/luis-how-to-azure-subscription#assign-a-resource-to-an-app
client.apps.update_settings(app_id, is_public=True)

responseEndpointInfo = client.apps.publish(app_id, versionId, is_staging=False)

# %% [markdown]
# ## Prédiction

# %%
runtimeCredentials = CognitiveServicesCredentials(predictionKey)
clientRuntime = LUISRuntimeClient(endpoint=predictionEndpoint,
                                  credentials=runtimeCredentials)

# %%
# Production == slot name
predictionRequest = {
    "query":
    'Hello I am from France and I need a flight to England from September 15 to October 28 with a budget of 3500'
}

predictionResponse = clientRuntime.prediction.get_slot_prediction(
    app_id, "Production", predictionRequest)
print("Top intent: {}".format(predictionResponse.prediction.top_intent))
print("Sentiment: {}".format(predictionResponse.prediction.sentiment))
print("Intents: ")

for intent in predictionResponse.prediction.intents:
    print("\t{}".format(json.dumps(intent)))
print("Entities: {}".format(predictionResponse.prediction.entities))
# Out:
# Top intent: Booking
# Sentiment: None
# Intents:
# 	"Booking"
# Entities: {'FlyOrder': [{'Fly': [{'or_city': ['France'], 'dst_city': ['England'], 'str_date': ['September 15'], 'end_date': ['October 28'], 'budget': ['3500']}]}], 'geographyV2': [{'value': 'England', 'type': 'state'}], 'datetimeV2': [{'type': 'daterange', 'values': [{'timex': '(XXXX-09-15,XXXX-10-28,P43D)', 'resolution': [{'start': '2022-09-15', 'end': '2022-10-28'}, {'start': '2023-09-15', 'end': '2023-10-28'}]}]}]}

# %% [markdown]
# Passons notre json de test à la prédiction, et récupérons les pour ensuite les ranger dans une dataframe.

# %%
df_test = pd.read_csv('data/test_df.csv',
                      parse_dates=['str_date_formate', 'end_date_formate'])

# %%
df_test.head()
# Out:
#                                                 text       or_city   dst_city  \
# 0  Three words: Alexandria to Cencun. Please book...    Alexandria     Cencun
# 1  Hello. I'm just gonna be honest with you, here...         Busan  Melbourne
# 2              Need two tickets out of Buenos Aires!  Buenos Aires        NaN
# 3             I need to get to Marseille from Dallas        Dallas  Marseille
# 4  Hi there, I'm looking for a trip for 5 between...        Tofino     Dallas
#
#    str_date end_date budget str_date_formate end_date_formate  budget_formate
# 0      ASAP    Sep 6    NaN              NaT       2022-09-06             NaN
# 1  the 23rd      NaN    NaN       2022-10-23              NaT             NaN
# 2       NaN      NaN    NaN              NaT              NaT             NaN
# 3       NaN      NaN    NaN              NaT              NaT             NaN
# 4    Aug 25   Aug 28    NaN       2022-08-25       2022-08-28             NaN

# %%
df_test_prediction = pd.DataFrame(
    columns=['text', 'or_city', 'dst_city', 'str_date', 'end_date', 'budget'])
df_test_prediction
# Out:
# Empty DataFrame
# Columns: [text, or_city, dst_city, str_date, end_date, budget]
# Index: []

# %%
# %%time
for i in range(len(df_test)):
    texte = df_test.loc[i]['text']

    predictionRequest = {"query": texte}

    predictionResponse = clientRuntime.prediction.get_slot_prediction(
        app_id, "Production", predictionRequest)

    prediction = predictionResponse.prediction.entities

    if prediction.get('FlyOrder') != None:
        if bool(prediction.get('FlyOrder')[0]) == True:
            prediction = prediction.get('FlyOrder')[0].get("Fly")[0]

            # Cette manière d'ajouter un élément au dictionnaire permet
            # d'avoir la key 'text' en premier dans le dictionnaire
            prediction_final = {"text": texte}
            prediction_final.update(prediction)
        else:
            prediction_final = {"text": texte}
            prediction_final.update(prediction)
    else:
        prediction_final = {"text": texte}
        prediction_final.update(prediction)

    df_test_prediction = df_test_prediction.append(prediction_final,
                                                   ignore_index=True)
# Out:
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# <timed exec>:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#
# KeyboardInterrupt

# %%
# Supprime le format liste pour n'en garder que son contenu
df_test_prediction = df_test_prediction.applymap(lambda x: x[0]
                                                 if isinstance(x, list) else x)
df_test_prediction
# Out:
#                                                  text       or_city  \
# 0   Three words: Alexandria to Cencun. Please book...           NaN
# 1   Hello. I'm just gonna be honest with you, here...         Busan
# 2               Need two tickets out of Buenos Aires!           NaN
# 3              I need to get to Marseille from Dallas        Dallas
# 4   Hi there, I'm looking for a trip for 5 between...           NaN
# 5   Hi i'm from Buenos Aires, and I want to book a...  Buenos Aires
# 6   Hey! Yes! The 5 of us are looking to go somewh...           NaN
# 7                             Can you get me to Kyoto           NaN
# 8   yeah, hey. i need to know if you operate out o...      Tel Aviv
# 9   I have investment meetings in Sao Paulo, the d...           NaN
# 10  Hi! I'm looking to book a trip somewhere betwe...           NaN
# 11  My wife and I just had our second baby and wou...           NaN
# 12  Hi! I have 9 days of vacation time. Can you fi...           NaN
# 13  How much would it cost to get to Guadalajara f...        Sydney
# 14  Hey I'd like to take my wife and five kids som...           NaN
# 15  Hi, I'm looking to book a flight to Berlin ple...           NaN
# 16        Goiania to Montreal on Sept 10 to 11th ONLY           NaN
# 17  ahhhh hey bud. I need to get the heck outta te...      tel aviv
# 18  Hey there! I'm looking to surprise the family ...           NaN
# 19  I would like to go to Nagoya please :slightly_...           NaN
# 20                               9 tickets 2 leon pls           NaN
# 21                               Need to get to Essen           NaN
# 22  emergency flight out of Kobe please!! get me o...          Kobe
# 23  I need to book a trip for me and Madonna to Bi...           NaN
# 24  Want to travel with me and my wife and my youn...    Birmingham
# 25  Please find a flight from Beijing to Kochi for...           NaN
# 26  u do buenos aires to hiroshima, and if so at w...           NaN
# 27  Take me from Beijing to Salvador from the 24th...           NaN
# 28                 I want to book a trip to Valencia!           NaN
# 29  I want to go to Leon from Nagoya between the 1...           NaN
# 30  I want to go to Fukuoka and I want to leave fr...           NaN
# 31  Portland to St. Petersburg please. Under 3300 ...           NaN
# 32  Hello - looking to go to Sao Paulo and I’m lea...           NaN
# 33  Hi, I'd like to go from Burlington to Valencia...    Burlington
# 34            i wanna go to sacramento from hiroshima           NaN
# 35  Hello. I have 12 vacation days saved up and I’...           NaN
# 36  ay i need to get my parents out of SL this mon...           NaN
# 37  Hello there! I'm trying to plan a vacation her...           NaN
# 38  hey, i'm looking to go to Theed from Caprica o...       Caprica
# 39  from Fukuoka to Leon between 6 and 11th of Sep...       Fukuoka
#
#        dst_city        str_date           end_date budget FlyOrder  \
# 0           NaN             NaN                NaN    NaN       {}
# 1     Melbourne     August 24th                NaN    NaN      NaN
# 2           NaN             NaN                NaN    NaN       {}
# 3     Marseille             NaN                NaN    NaN      NaN
# 4           NaN             NaN                NaN    NaN       {}
# 5           NaN             NaN                NaN    NaN      NaN
# 6           NaN             NaN                NaN    NaN       {}
# 7         Kyoto             NaN                NaN    NaN      NaN
# 8           NaN             NaN                NaN    NaN      NaN
# 9           NaN             NaN                NaN    NaN       {}
# 10          NaN     August 19th      September 3rd   1700      NaN
# 11          NaN             NaN                NaN    NaN       {}
# 12          NaN             NaN                NaN    NaN       {}
# 13  Guadalajara             NaN                NaN    NaN      NaN
# 14          NaN             NaN                NaN    NaN       {}
# 15       Berlin             NaN                NaN    NaN      NaN
# 16          NaN             NaN                NaN    NaN       {}
# 17       London             NaN                NaN    NaN      NaN
# 18          NaN             NaN                NaN    NaN       {}
# 19       Nagoya             NaN                NaN    NaN      NaN
# 20          NaN             NaN                NaN    NaN       {}
# 21          NaN             NaN                NaN    NaN       {}
# 22    fortaleza  september 16th                NaN    NaN      NaN
# 23          NaN             NaN                NaN    NaN       {}
# 24     Curitiba             NaN                NaN   4000      NaN
# 25          NaN             NaN                NaN    NaN       {}
# 26          NaN             NaN                NaN    NaN       {}
# 27          NaN             NaN                NaN    NaN       {}
# 28          NaN             NaN                NaN    NaN       {}
# 29          NaN             NaN                NaN    NaN       {}
# 30          NaN             NaN                NaN    NaN       {}
# 31          NaN             NaN                NaN    NaN       {}
# 32          NaN             NaN                NaN    NaN       {}
# 33     Valencia             NaN                NaN  19900      NaN
# 34          NaN             NaN                NaN    NaN       {}
# 35          NaN             NaN                NaN    NaN       {}
# 36          NaN             NaN                NaN    NaN       {}
# 37          NaN             NaN                NaN    NaN       {}
# 38        Theed     August 13th                NaN    NaN      NaN
# 39          NaN             NaN  11th of September    NaN      NaN
#
#                                            datetimeV2  \
# 0   {'type': 'datetime', 'values': [{'timex': 'FUT...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   {'type': 'daterange', 'values': [{'timex': '(X...
# 5                                                 NaN
# 6   {'type': 'daterange', 'values': [{'timex': '(X...
# 7                                                 NaN
# 8                                                 NaN
# 9   {'type': 'datetime', 'values': [{'timex': 'FUT...
# 10                                                NaN
# 11                                                NaN
# 12  {'type': 'duration', 'values': [{'timex': 'P9D...
# 13                                                NaN
# 14  {'type': 'daterange', 'values': [{'timex': '(X...
# 15                                                NaN
# 16  {'type': 'daterange', 'values': [{'timex': '(X...
# 17                                                NaN
# 18  {'type': 'date', 'values': [{'timex': 'XXXX-09...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25  {'type': 'daterange', 'values': [{'timex': '(X...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  {'type': 'date', 'values': [{'timex': 'XXXX-10...
# 30                                                NaN
# 31  {'type': 'daterange', 'values': [{'timex': '(X...
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35  {'type': 'daterange', 'values': [{'timex': 'XX...
# 36  {'type': 'daterange', 'values': [{'timex': '20...
# 37  {'type': 'daterange', 'values': [{'timex': '(X...
# 38                                                NaN
# 39                                                NaN
#
#                                    geographyV2
# 0                                          NaN
# 1                                          NaN
# 2    {'value': 'Buenos Aires', 'type': 'city'}
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9       {'value': 'Sao Paulo', 'type': 'city'}
# 10                                         NaN
# 11     {'value': 'Queenstown', 'type': 'city'}
# 12  {'value': 'Ciudad Juarez', 'type': 'city'}
# 13                                         NaN
# 14       {'value': 'San Jose', 'type': 'city'}
# 15                                         NaN
# 16        {'value': 'Goiania', 'type': 'city'}
# 17                                         NaN
# 18         {'value': 'London', 'type': 'city'}
# 19                                         NaN
# 20                                         NaN
# 21          {'value': 'Essen', 'type': 'city'}
# 22                                         NaN
# 23         {'value': 'Madonna', 'type': 'poi'}
# 24                                         NaN
# 25        {'value': 'Beijing', 'type': 'city'}
# 26   {'value': 'buenos aires', 'type': 'city'}
# 27        {'value': 'Beijing', 'type': 'city'}
# 28       {'value': 'Valencia', 'type': 'city'}
# 29           {'value': 'Leon', 'type': 'city'}
# 30        {'value': 'Fukuoka', 'type': 'city'}
# 31       {'value': 'Portland', 'type': 'city'}
# 32      {'value': 'Sao Paulo', 'type': 'city'}
# 33                                         NaN
# 34     {'value': 'sacramento', 'type': 'city'}
# 35    {'value': 'Mexico City', 'type': 'city'}
# 36      {'value': 'St. Louis', 'type': 'city'}
# 37                                         NaN
# 38                                         NaN
# 39                                         NaN

# %% [markdown]
# Nous avons quelques colonnes supplémentaires qui concernent les prébuilt, nous les utiliserons peut-être plus tard si nous voulons prendre en compte ces derniers dans le score final du modèle. Exportons notre dataframe de prédiction.

# %%
# df_test_prediction.to_csv('data/df_prediction.csv', index=None)
df_test_prediction = pd.read_csv('data/df_prediction.csv')
df_test_prediction
# Out:
#                                                   text        or_city  \
# 0    Three words: Alexandria to Cencun. Please book...            NaN
# 1    Hello. I'm just gonna be honest with you, here...          Busan
# 2                Need two tickets out of Buenos Aires!            NaN
# 3               I need to get to Marseille from Dallas         Dallas
# 4    Hi there, I'm looking for a trip for 5 between...            NaN
# ..                                                 ...            ...
# 195  Hello. I am a deeply tormented children’s writ...            NaN
# 196  I have a business trip coming up in Punta Cana...            NaN
# 197                                   Melbourne please            NaN
# 198  Good morning! So I just won the lottery and de...  San Francisco
# 199      BRASILIA TO KYOTO, SEPT 4. $4000 Budget GOOOO            NaN
#
#        dst_city     str_date end_date budget FlyOrder  \
# 0           NaN          NaN      NaN    NaN       {}
# 1     Melbourne  August 24th      NaN    NaN      NaN
# 2           NaN          NaN      NaN    NaN       {}
# 3     Marseille          NaN      NaN    NaN      NaN
# 4           NaN          NaN      NaN    NaN       {}
# ..          ...          ...      ...    ...      ...
# 195         NaN          NaN      NaN    NaN       {}
# 196  Punta Cana          NaN      NaN    NaN      NaN
# 197         NaN          NaN      NaN    NaN       {}
# 198  Sacramento          NaN      NaN    NaN      NaN
# 199         NaN          NaN      NaN    NaN       {}
#
#                                             datetimeV2  \
# 0    {'type': 'datetime', 'values': [{'timex': 'FUT...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    {'type': 'daterange', 'values': [{'timex': '(X...
# ..                                                 ...
# 195  {'type': 'daterange', 'values': [{'timex': '20...
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199  {'type': 'date', 'values': [{'timex': 'XXXX-09...
#
#                                    geographyV2  \
# 0                                          NaN
# 1                                          NaN
# 2    {'value': 'Buenos Aires', 'type': 'city'}
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 195   {'value': 'Minneapolis', 'type': 'city'}
# 196                                        NaN
# 197     {'value': 'Melbourne', 'type': 'city'}
# 198                                        NaN
# 199      {'value': 'BRASILIA', 'type': 'city'}
#
#                                    money
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 195  {'number': 2000, 'units': 'Dollar'}
# 196                                  NaN
# 197                                  NaN
# 198                                  NaN
# 199  {'number': 4000, 'units': 'Dollar'}
#
# [200 rows x 10 columns]

# %%
def parse_date(date):
    try:
        return parse(date, fuzzy_with_tokens=True)[0]
    except:
        return np.nan

# %%
# Nous formatons les prédictions au bon format
df_test_prediction['str_date'] = df_test_prediction['str_date'].apply(
    parse_date)
df_test_prediction['end_date'] = df_test_prediction['end_date'].apply(
    parse_date)

# %%
df_test_prediction
# Out:
#                                                   text        or_city  \
# 0    Three words: Alexandria to Cencun. Please book...            NaN
# 1    Hello. I'm just gonna be honest with you, here...          Busan
# 2                Need two tickets out of Buenos Aires!            NaN
# 3               I need to get to Marseille from Dallas         Dallas
# 4    Hi there, I'm looking for a trip for 5 between...            NaN
# ..                                                 ...            ...
# 195  Hello. I am a deeply tormented children’s writ...            NaN
# 196  I have a business trip coming up in Punta Cana...            NaN
# 197                                   Melbourne please            NaN
# 198  Good morning! So I just won the lottery and de...  San Francisco
# 199      BRASILIA TO KYOTO, SEPT 4. $4000 Budget GOOOO            NaN
#
#        dst_city   str_date end_date budget FlyOrder  \
# 0           NaN        NaT      NaT    NaN       {}
# 1     Melbourne 2022-08-24      NaT    NaN      NaN
# 2           NaN        NaT      NaT    NaN       {}
# 3     Marseille        NaT      NaT    NaN      NaN
# 4           NaN        NaT      NaT    NaN       {}
# ..          ...        ...      ...    ...      ...
# 195         NaN        NaT      NaT    NaN       {}
# 196  Punta Cana        NaT      NaT    NaN      NaN
# 197         NaN        NaT      NaT    NaN       {}
# 198  Sacramento        NaT      NaT    NaN      NaN
# 199         NaN        NaT      NaT    NaN       {}
#
#                                             datetimeV2  \
# 0    {'type': 'datetime', 'values': [{'timex': 'FUT...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    {'type': 'daterange', 'values': [{'timex': '(X...
# ..                                                 ...
# 195  {'type': 'daterange', 'values': [{'timex': '20...
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199  {'type': 'date', 'values': [{'timex': 'XXXX-09...
#
#                                    geographyV2  \
# 0                                          NaN
# 1                                          NaN
# 2    {'value': 'Buenos Aires', 'type': 'city'}
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 195   {'value': 'Minneapolis', 'type': 'city'}
# 196                                        NaN
# 197     {'value': 'Melbourne', 'type': 'city'}
# 198                                        NaN
# 199      {'value': 'BRASILIA', 'type': 'city'}
#
#                                    money
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 195  {'number': 2000, 'units': 'Dollar'}
# 196                                  NaN
# 197                                  NaN
# 198                                  NaN
# 199  {'number': 4000, 'units': 'Dollar'}
#
# [200 rows x 10 columns]

# %% [markdown]
# ## Formatage des données prébuilt

# %% [markdown]
# ### Date

# %% [markdown]
# Nous devons maintenant formater les données prédites par les prébuilts, nous pourrons alors comparer le score du modèle de base, puis le score du modèle si nous ajoutons les prédictions du prébuilt.

# %%
for i in df_test_prediction["datetimeV2"]:
    print(i)
# Out:
# {'type': 'datetime', 'values': [{'timex': 'FUTURE_REF', 'resolution': [{'value': '2022-10-28 17:00:44'}]}]}
# nan
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': '(XXXX-08-25,XXXX-08-28,P3D)', 'resolution': [{'start': '2022-08-25', 'end': '2022-08-28'}, {'start': '2023-08-25', 'end': '2023-08-28'}]}]}
# nan
# {'type': 'daterange', 'values': [{'timex': '(XXXX-09-13,XXXX-09-22,P9D)', 'resolution': [{'start': '2022-09-13', 'end': '2022-09-22'}, {'start': '2023-09-13', 'end': '2023-09-22'}]}]}
# nan
# nan
# {'type': 'datetime', 'values': [{'timex': 'FUTURE_REF', 'resolution': [{'value': '2022-10-28 17:00:47'}]}]}
# nan
# nan
# {'type': 'duration', 'values': [{'timex': 'P9D', 'resolution': [{'value': '777600'}]}]}
# nan
# {'type': 'daterange', 'values': [{'timex': '(XXXX-09-01,XXXX-09-16,P15D)', 'resolution': [{'start': '2022-09-01', 'end': '2022-09-16'}, {'start': '2023-09-01', 'end': '2023-09-16'}]}]}
# nan
# {'type': 'daterange', 'values': [{'timex': '(XXXX-09-10,XXXX-09-11,P1D)', 'resolution': [{'start': '2022-09-10', 'end': '2022-09-11'}, {'start': '2023-09-10', 'end': '2023-09-11'}]}]}
# nan
# {'type': 'date', 'values': [{'timex': 'XXXX-09-06', 'resolution': [{'value': '2022-09-06'}, {'value': '2023-09-06'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': '(XXXX-09-16,XXXX-09-20,P4D)', 'resolution': [{'start': '2022-09-16', 'end': '2022-09-20'}, {'start': '2023-09-16', 'end': '2023-09-20'}]}]}
# nan
# nan
# nan
# {'type': 'date', 'values': [{'timex': 'XXXX-10-02', 'resolution': [{'value': '2022-10-02'}, {'value': '2023-10-02'}]}]}
# nan
# {'type': 'daterange', 'values': [{'timex': '(XXXX-09-13,XXXX-09-17,P4D)', 'resolution': [{'start': '2022-09-13', 'end': '2022-09-17'}, {'start': '2023-09-13', 'end': '2023-09-17'}]}]}
# nan
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': 'XXXX-09-12', 'mod': 'before', 'resolution': [{'sourceEntity': 'datetimepoint', 'end': '2022-09-12'}, {'sourceEntity': 'datetimepoint', 'end': '2023-09-12'}]}]}
# {'type': 'daterange', 'values': [{'timex': '2022-10', 'resolution': [{'start': '2022-10-01', 'end': '2022-11-01'}]}]}
# {'type': 'daterange', 'values': [{'timex': '(XXXX-08-27,XXXX-09-16,P20D)', 'resolution': [{'start': '2022-08-27', 'end': '2022-09-16'}, {'start': '2023-08-27', 'end': '2023-09-16'}]}]}
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': '(2022-10-29,XXXX-09-26,P332D)', 'resolution': [{'start': '2022-10-29', 'end': '2023-09-26'}]}]}
# nan
# nan
# nan
# nan
# {'type': 'datetime', 'values': [{'timex': 'PRESENT_REF', 'resolution': [{'value': '2022-10-28 17:00:56'}]}]}
# nan
# nan
# nan
# {'type': 'datetime', 'values': [{'timex': 'FUTURE_REF', 'resolution': [{'value': '2022-10-28 17:00:57'}]}]}
# nan
# nan
# nan
# {'type': 'date', 'values': [{'timex': 'XXXX-08-19', 'resolution': [{'value': '2022-08-19'}, {'value': '2023-08-19'}]}]}
# nan
# nan
# nan
# nan
# {'type': 'date', 'values': [{'timex': 'XXXX-08-27', 'resolution': [{'value': '2022-08-27'}, {'value': '2023-08-27'}]}]}
# nan
# {'type': 'daterange', 'values': [{'timex': '(XXXX-09-08,XXXX-09-29,P21D)', 'resolution': [{'start': '2022-09-08', 'end': '2022-09-29'}, {'start': '2023-09-08', 'end': '2023-09-29'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': 'SP', 'resolution': [{'value': 'not resolved'}]}]}
# {'type': 'daterange', 'values': [{'timex': '(XXXX-09-24,XXXX-09-27,P3D)', 'resolution': [{'start': '2022-09-24', 'end': '2022-09-27'}, {'start': '2023-09-24', 'end': '2023-09-27'}]}]}
# {'type': 'daterange', 'values': [{'timex': '(XXXX-08-25,XXXX-09-09,P15D)', 'resolution': [{'start': '2022-08-25', 'end': '2022-09-09'}, {'start': '2023-08-25', 'end': '2023-09-09'}]}]}
# nan
# nan
# nan
# nan
# nan
# {'type': 'datetime', 'values': [{'timex': 'PRESENT_REF', 'resolution': [{'value': '2022-10-28 17:01:05'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'date', 'values': [{'timex': 'XXXX-XX-17', 'resolution': [{'value': '2022-10-17'}, {'value': '2022-11-17'}]}]}
# {'type': 'daterange', 'values': [{'timex': '(XXXX-08-30,XXXX-09-10,P11D)', 'resolution': [{'start': '2022-08-30', 'end': '2022-09-10'}, {'start': '2023-08-30', 'end': '2023-09-10'}]}]}
# {'type': 'daterange', 'values': [{'timex': '(XXXX-09-17,XXXX-10-08,P21D)', 'resolution': [{'start': '2022-09-17', 'end': '2022-10-08'}, {'start': '2023-09-17', 'end': '2023-10-08'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'duration', 'values': [{'timex': 'P14D', 'resolution': [{'value': '1209600'}]}]}
# nan
# nan
# {'type': 'date', 'values': [{'timex': 'XXXX-09-08', 'resolution': [{'value': '2022-09-08'}, {'value': '2023-09-08'}]}]}
# nan
# {'type': 'daterange', 'values': [{'timex': 'XXXX-09-06', 'mod': 'before', 'resolution': [{'sourceEntity': 'datetimepoint', 'end': '2022-09-06'}, {'sourceEntity': 'datetimepoint', 'end': '2023-09-06'}]}]}
# nan
# nan
# {'type': 'set', 'values': [{'timex': 'P1W', 'resolution': [{'value': 'not resolved'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': '(XXXX-08-27,XXXX-09-16,P20D)', 'resolution': [{'start': '2022-08-27', 'end': '2022-09-16'}, {'start': '2023-08-27', 'end': '2023-09-16'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'date', 'values': [{'timex': 'XXXX-09-13', 'resolution': [{'value': '2022-09-13'}, {'value': '2023-09-13'}]}]}
# nan
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': '(XXXX-08-31,XXXX-09-09,P9D)', 'resolution': [{'start': '2022-08-31', 'end': '2022-09-09'}, {'start': '2023-08-31', 'end': '2023-09-09'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': '2022', 'resolution': [{'start': '2022-01-01', 'end': '2023-01-01'}]}]}
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': '1600', 'resolution': [{'start': '1600-01-01', 'end': '1601-01-01'}]}]}
# {'type': 'duration', 'values': [{'timex': 'P9D', 'resolution': [{'value': '777600'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'date', 'values': [{'timex': 'XXXX-09-24', 'resolution': [{'value': '2022-09-24'}, {'value': '2023-09-24'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': '(XXXX-08-30,XXXX-09-02,P3D)', 'resolution': [{'start': '2022-08-30', 'end': '2022-09-02'}, {'start': '2023-08-30', 'end': '2023-09-02'}]}]}
# nan
# {'type': 'date', 'values': [{'timex': '2022-11-01', 'resolution': [{'value': '2022-11-01'}]}]}
# nan
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': 'XXXX-08-28', 'mod': 'since', 'resolution': [{'sourceEntity': 'datetimepoint', 'start': '2022-08-28'}, {'sourceEntity': 'datetimepoint', 'start': '2023-08-28'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'date', 'values': [{'timex': 'XXXX-08-31', 'resolution': [{'value': '2022-08-31'}, {'value': '2023-08-31'}]}]}
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# {'type': 'datetime', 'values': [{'timex': 'FUTURE_REF', 'resolution': [{'value': '2022-10-28 17:01:30'}]}]}
# nan
# {'type': 'daterange', 'values': [{'timex': '2022-W44', 'resolution': [{'start': '2022-10-31', 'end': '2022-11-07'}]}]}
# nan
# {'type': 'duration', 'values': [{'timex': 'P6D', 'resolution': [{'value': '518400'}]}]}
# nan
# nan
# {'type': 'daterange', 'values': [{'timex': '2000', 'resolution': [{'start': '2000-01-01', 'end': '2001-01-01'}]}]}
# nan
# nan
# nan
# {'type': 'date', 'values': [{'timex': 'XXXX-09-04', 'resolution': [{'value': '2022-09-04'}, {'value': '2023-09-04'}]}]}

# %%
# Suppression des string pour lire les dictionnaires
df_test_prediction_avec_prebuilt = df_test_prediction.applymap(
    lambda x: x[0] if isinstance(x, list) else x).copy()
df_test_prediction_avec_prebuilt["date_prebuilt_start"] = np.nan
df_test_prediction_avec_prebuilt["date_prebuilt_end"] = np.nan
df_test_prediction_avec_prebuilt["date_prebuilt_inconnu"] = np.nan

for i in range(len(df_test_prediction_avec_prebuilt)):
    try:
        dict_sans_string = eval(
            df_test_prediction_avec_prebuilt["datetimeV2"][i])
        resolution = dict_sans_string.get("values")[0].get("resolution")[0]
        # Si start et end sont les clefs du dict resolution
        if "start" and "end" in resolution:
            df_test_prediction_avec_prebuilt["date_prebuilt_start"][
                i] = resolution.get("start")
            df_test_prediction_avec_prebuilt["date_prebuilt_end"][
                i] = resolution.get("end")
        elif "value" in resolution:
            df_test_prediction_avec_prebuilt["date_prebuilt_inconnu"][
                i] = resolution.get("value")
    except:
        pass
# Out:
# D:\Temp\ipykernel_11176\996813107.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_prediction_avec_prebuilt["date_prebuilt_inconnu"][i] = resolution.get("value")
# D:\Temp\ipykernel_11176\996813107.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_prediction_avec_prebuilt["date_prebuilt_start"][i] = resolution.get("start")
# D:\Temp\ipykernel_11176\996813107.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_prediction_avec_prebuilt["date_prebuilt_end"][i] = resolution.get("end")

# %%
df_test_prediction_avec_prebuilt.head(5)
# Out:
#                                                   text        or_city  \
# 0    Three words: Alexandria to Cencun. Please book...            NaN
# 1    Hello. I'm just gonna be honest with you, here...          Busan
# 2                Need two tickets out of Buenos Aires!            NaN
# 3               I need to get to Marseille from Dallas         Dallas
# 4    Hi there, I'm looking for a trip for 5 between...            NaN
# ..                                                 ...            ...
# 195  Hello. I am a deeply tormented children’s writ...            NaN
# 196  I have a business trip coming up in Punta Cana...            NaN
# 197                                   Melbourne please            NaN
# 198  Good morning! So I just won the lottery and de...  San Francisco
# 199      BRASILIA TO KYOTO, SEPT 4. $4000 Budget GOOOO            NaN
#
#        dst_city   str_date end_date budget FlyOrder  \
# 0           NaN        NaT      NaT    NaN       {}
# 1     Melbourne 2022-08-24      NaT    NaN      NaN
# 2           NaN        NaT      NaT    NaN       {}
# 3     Marseille        NaT      NaT    NaN      NaN
# 4           NaN        NaT      NaT    NaN       {}
# ..          ...        ...      ...    ...      ...
# 195         NaN        NaT      NaT    NaN       {}
# 196  Punta Cana        NaT      NaT    NaN      NaN
# 197         NaN        NaT      NaT    NaN       {}
# 198  Sacramento        NaT      NaT    NaN      NaN
# 199         NaN        NaT      NaT    NaN       {}
#
#                                             datetimeV2  \
# 0    {'type': 'datetime', 'values': [{'timex': 'FUT...
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    {'type': 'daterange', 'values': [{'timex': '(X...
# ..                                                 ...
# 195  {'type': 'daterange', 'values': [{'timex': '20...
# 196                                                NaN
# 197                                                NaN
# 198                                                NaN
# 199  {'type': 'date', 'values': [{'timex': 'XXXX-09...
#
#                                    geographyV2  \
# 0                                          NaN
# 1                                          NaN
# 2    {'value': 'Buenos Aires', 'type': 'city'}
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 195   {'value': 'Minneapolis', 'type': 'city'}
# 196                                        NaN
# 197     {'value': 'Melbourne', 'type': 'city'}
# 198                                        NaN
# 199      {'value': 'BRASILIA', 'type': 'city'}
#
#                                    money date_prebuilt_start  \
# 0                                    NaN                 NaN
# 1                                    NaN                 NaN
# 2                                    NaN                 NaN
# 3                                    NaN                 NaN
# 4                                    NaN          2022-08-25
# ..                                   ...                 ...
# 195  {'number': 2000, 'units': 'Dollar'}          2000-01-01
# 196                                  NaN                 NaN
# 197                                  NaN                 NaN
# 198                                  NaN                 NaN
# 199  {'number': 4000, 'units': 'Dollar'}                 NaN
#
#     date_prebuilt_end date_prebuilt_inconnu
# 0                 NaN   2022-10-28 17:00:44
# 1                 NaN                   NaN
# 2                 NaN                   NaN
# 3                 NaN                   NaN
# 4          2022-08-28                   NaN
# ..                ...                   ...
# 195        2001-01-01                   NaN
# 196               NaN                   NaN
# 197               NaN                   NaN
# 198               NaN                   NaN
# 199               NaN            2022-09-04
#
# [200 rows x 13 columns]

# %% [markdown]
# Nous avons donc toutes les dates bien formatées. Nous verrons de ce que nous ferons des dates sans "start" ni "end".

# %% [markdown]
# ### Budget

# %% [markdown]
# Commençons le formatage de la colonne money (budget).

# %%
def parse_price(price):
    try:
        price = Price.fromstring(price, decimal_separator=".")
        return price.amount_float
    except:
        return np.nan

# %%
df_test_prediction_avec_prebuilt["money"].dropna()
# Out:
# 45       {'number': 3900, 'units': 'Dollar'}
# 51       {'number': 6200, 'units': 'Dollar'}
# 88          {'number': 0, 'units': 'Dollar'}
# 101    {'number': 400.14, 'units': 'Dollar'}
# 171      {'number': 6200, 'units': 'Dollar'}
# 195      {'number': 2000, 'units': 'Dollar'}
# 199      {'number': 4000, 'units': 'Dollar'}
# Name: money, dtype: object

# %%
df_test_prediction_avec_prebuilt['money'] = df_test_prediction_avec_prebuilt[
    'money'].apply(parse_price)

# %%
df_test_prediction_avec_prebuilt['money']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#         ...
# 195    2000.0
# 196       NaN
# 197       NaN
# 198       NaN
# 199    4000.0
# Name: money, Length: 200, dtype: float64

# %% [markdown]
# Nous avons terminé de formater le prebuilt money, passons maintenant à geographyV2.

# %% [markdown]
# ### Geography

# %%
df_test_prediction_avec_prebuilt["geographyV2"].dropna()
# Out:
# 2       {'value': 'Buenos Aires', 'type': 'city'}
# 9          {'value': 'Sao Paulo', 'type': 'city'}
# 11        {'value': 'Queenstown', 'type': 'city'}
# 12     {'value': 'Ciudad Juarez', 'type': 'city'}
# 14          {'value': 'San Jose', 'type': 'city'}
#                           ...
# 190         {'value': 'Curitiba', 'type': 'city'}
# 192       {'value': 'queenstown', 'type': 'city'}
# 195      {'value': 'Minneapolis', 'type': 'city'}
# 197        {'value': 'Melbourne', 'type': 'city'}
# 199         {'value': 'BRASILIA', 'type': 'city'}
# Name: geographyV2, Length: 92, dtype: object

# %% [markdown]
# Le problème que nous avons ici, c'est que nous n’avons qu'une seule valeur de détectée, nous ne savons pas si cette valeur est pour la destination ou l'origine.
#
# Nous allons donc simplement formater cette colonne de manière à n'avoir que la région. Et nous verrons ce que nous ferons de cette colonne plus tard.

# %%
def pays_ville(localisation):
    try:
        locat = eval(localisation)
        return locat.get("value")
    except:
        return np.nan

# %%
df_test_prediction_avec_prebuilt[
    "geographyV2"] = df_test_prediction_avec_prebuilt["geographyV2"].apply(
        pays_ville)

# %%
df_test_prediction_avec_prebuilt["geographyV2"].dropna()
# Out:
# 2       Buenos Aires
# 9          Sao Paulo
# 11        Queenstown
# 12     Ciudad Juarez
# 14          San Jose
#            ...
# 190         Curitiba
# 192       queenstown
# 195      Minneapolis
# 197        Melbourne
# 199         BRASILIA
# Name: geographyV2, Length: 92, dtype: object

# %%
df_test_prediction_avec_prebuilt[[
    "or_city", "dst_city", "geographyV2"
]][df_test_prediction_avec_prebuilt['geographyV2'].notna()]
# Out:
#     or_city dst_city    geographyV2
# 2       NaN      NaN   Buenos Aires
# 9       NaN      NaN      Sao Paulo
# 11      NaN      NaN     Queenstown
# 12      NaN      NaN  Ciudad Juarez
# 14      NaN      NaN       San Jose
# ..      ...      ...            ...
# 190     NaN      NaN       Curitiba
# 192     NaN      NaN     queenstown
# 195     NaN      NaN    Minneapolis
# 197     NaN      NaN      Melbourne
# 199     NaN      NaN       BRASILIA
#
# [92 rows x 3 columns]

# %% [markdown]
# Nous avons maintenant terminé le formatage de nos colonnes, passons au scoring.

# %% [markdown]
# ## Scoring

# %%
df_test_prediction_avec_prebuilt.head(5)
# Out:
#                                                 text or_city   dst_city  \
# 0  Three words: Alexandria to Cencun. Please book...     NaN        NaN
# 1  Hello. I'm just gonna be honest with you, here...   Busan  Melbourne
# 2              Need two tickets out of Buenos Aires!     NaN        NaN
# 3             I need to get to Marseille from Dallas  Dallas  Marseille
# 4  Hi there, I'm looking for a trip for 5 between...     NaN        NaN
#
#     str_date end_date budget FlyOrder  \
# 0        NaT      NaT    NaN       {}
# 1 2022-08-24      NaT    NaN      NaN
# 2        NaT      NaT    NaN       {}
# 3        NaT      NaT    NaN      NaN
# 4        NaT      NaT    NaN       {}
#
#                                           datetimeV2   geographyV2  money  \
# 0  {'type': 'datetime', 'values': [{'timex': 'FUT...           NaN    NaN
# 1                                                NaN           NaN    NaN
# 2                                                NaN  Buenos Aires    NaN
# 3                                                NaN           NaN    NaN
# 4  {'type': 'daterange', 'values': [{'timex': '(X...           NaN    NaN
#
#   date_prebuilt_start date_prebuilt_end date_prebuilt_inconnu
# 0                 NaN               NaN   2022-10-28 17:00:44
# 1                 NaN               NaN                   NaN
# 2                 NaN               NaN                   NaN
# 3                 NaN               NaN                   NaN
# 4          2022-08-25        2022-08-28                   NaN

# %%
# Merge des dataframes de test et de prediction
df_merged = pd.merge(df_test_prediction_avec_prebuilt[[
    "text", "or_city", "dst_city", "str_date", "end_date", "budget",
    "date_prebuilt_start", "date_prebuilt_end", "date_prebuilt_inconnu",
    "money", "geographyV2"
]],
                     df_test[[
                         "text", "or_city", "dst_city", "str_date", "end_date",
                         "budget", "str_date_formate", "end_date_formate",
                         "budget_formate"
                     ]],
                     on=['text'])
df_merged.head(5)
# Out:
#                                                 text or_city_x dst_city_x  \
# 0  Three words: Alexandria to Cencun. Please book...       NaN        NaN
# 1  Hello. I'm just gonna be honest with you, here...     Busan  Melbourne
# 2              Need two tickets out of Buenos Aires!       NaN        NaN
# 3             I need to get to Marseille from Dallas    Dallas  Marseille
# 4  Hi there, I'm looking for a trip for 5 between...       NaN        NaN
#
#   str_date_x end_date_x budget_x date_prebuilt_start date_prebuilt_end  \
# 0        NaT        NaT      NaN                 NaN               NaN
# 1 2022-08-24        NaT      NaN                 NaN               NaN
# 2        NaT        NaT      NaN                 NaN               NaN
# 3        NaT        NaT      NaN                 NaN               NaN
# 4        NaT        NaT      NaN          2022-08-25        2022-08-28
#
#   date_prebuilt_inconnu  money   geographyV2     or_city_y dst_city_y  \
# 0   2022-10-28 17:00:44    NaN           NaN    Alexandria     Cencun
# 1                   NaN    NaN           NaN         Busan  Melbourne
# 2                   NaN    NaN  Buenos Aires  Buenos Aires        NaN
# 3                   NaN    NaN           NaN        Dallas  Marseille
# 4                   NaN    NaN           NaN        Tofino     Dallas
#
#   str_date_y end_date_y budget_y str_date_formate end_date_formate  \
# 0       ASAP      Sep 6      NaN              NaT       2022-09-06
# 1   the 23rd        NaN      NaN       2022-10-23              NaT
# 2        NaN        NaN      NaN              NaT              NaT
# 3        NaN        NaN      NaN              NaT              NaT
# 4     Aug 25     Aug 28      NaN       2022-08-25       2022-08-28
#
#    budget_formate
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %% [markdown]
# Nous allons commencer la comparaison avec notre modèle de base sans utiliser les prébuilt. Nous ne prendrons que les colonnes qui ont été bien formatées, les autres ne seront pas utiles.

# %%
df_score_sans_prebuilt = df_merged[[
    "or_city_x", "dst_city_x", "str_date_x", "end_date_x", "budget_x",
    "or_city_y", "dst_city_y", "str_date_formate", "end_date_formate",
    "budget_formate"
]]

# %%
df_score_sans_prebuilt.head(5)
# Out:
#   or_city_x dst_city_x str_date_x end_date_x budget_x     or_city_y  \
# 0       NaN        NaN        NaT        NaT      NaN    Alexandria
# 1     Busan  Melbourne 2022-08-24        NaT      NaN         Busan
# 2       NaN        NaN        NaT        NaT      NaN  Buenos Aires
# 3    Dallas  Marseille        NaT        NaT      NaN        Dallas
# 4       NaN        NaN        NaT        NaT      NaN        Tofino
#
#   dst_city_y str_date_formate end_date_formate  budget_formate
# 0     Cencun              NaT       2022-09-06             NaN
# 1  Melbourne       2022-10-23              NaT             NaN
# 2        NaN              NaT              NaT             NaN
# 3  Marseille              NaT              NaT             NaN
# 4     Dallas       2022-08-25       2022-08-28             NaN

# %%
df_score_sans_prebuilt = df_score_sans_prebuilt.fillna("0")
df_score_sans_prebuilt.head(5)
# Out:
#   or_city_x dst_city_x           str_date_x end_date_x budget_x     or_city_y  \
# 0         0          0                    0          0        0    Alexandria
# 1     Busan  Melbourne  2022-08-24 00:00:00          0        0         Busan
# 2         0          0                    0          0        0  Buenos Aires
# 3    Dallas  Marseille                    0          0        0        Dallas
# 4         0          0                    0          0        0        Tofino
#
#   dst_city_y     str_date_formate     end_date_formate budget_formate
# 0     Cencun                    0  2022-09-06 00:00:00              0
# 1  Melbourne  2022-10-23 00:00:00                    0              0
# 2          0                    0                    0              0
# 3  Marseille                    0                    0              0
# 4     Dallas  2022-08-25 00:00:00  2022-08-28 00:00:00              0

# %% [markdown]
# Nous allons maintenant comparer chaques valeurs de chaque colonnes **x(target)** et **y(pred) | formate** à chaque lignes.
#
# Puis, pour chaque bonne prédiction, 1 points sera ajouté à la colonne "Score" de la même ligne (les valeurs 0 qui correspondent aux NaN ne seront évidement pas pris en compte).

# %%
list_columns_pred = [
    "or_city_x", "dst_city_x", "str_date_x", "end_date_x", "budget_x"
]
list_columns_target = [
    "or_city_y", "dst_city_y", "str_date_formate", "end_date_formate",
    "budget_formate"
]
df_score_sans_prebuilt['Score'] = 0

for i in range(len(df_test)):
    df_score_sans_prebuilt["Score"].iloc[i] = 0
    for colonne_x, colonne_y in zip(list_columns_target, list_columns_pred):
        if df_score_sans_prebuilt[colonne_y].iloc[i] != "0":
            if df_score_sans_prebuilt[colonne_y].iloc[
                    i] == df_score_sans_prebuilt[colonne_x].iloc[i]:
                df_score_sans_prebuilt["Score"].iloc[i] += 1
# Out:
# D:\Temp\ipykernel_11176\1063619686.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_score_sans_prebuilt["Score"].iloc[i] = 0
# D:\Temp\ipykernel_11176\1063619686.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_score_sans_prebuilt["Score"].iloc[i] += 1

# %%
quantite_bonne_reponse = df_score_sans_prebuilt["Score"].sum()
quantite_bonne_reponse
# Out:
# 138

# %%
df_score_sans_prebuilt
# Out:
#          or_city_x  dst_city_x           str_date_x end_date_x budget_x  \
# 0                0           0                    0          0        0
# 1            Busan   Melbourne  2022-08-24 00:00:00          0        0
# 2                0           0                    0          0        0
# 3           Dallas   Marseille                    0          0        0
# 4                0           0                    0          0        0
# ..             ...         ...                  ...        ...      ...
# 195              0           0                    0          0        0
# 196              0  Punta Cana                    0          0        0
# 197              0           0                    0          0        0
# 198  San Francisco  Sacramento                    0          0        0
# 199              0           0                    0          0        0
#
#          or_city_y  dst_city_y     str_date_formate     end_date_formate  \
# 0       Alexandria      Cencun                    0  2022-09-06 00:00:00
# 1            Busan   Melbourne  2022-10-23 00:00:00                    0
# 2     Buenos Aires           0                    0                    0
# 3           Dallas   Marseille                    0                    0
# 4           Tofino      Dallas  2022-08-25 00:00:00  2022-08-28 00:00:00
# ..             ...         ...                  ...                  ...
# 195    Minneapolis        Lima                    0                    0
# 196     Punta Cana      Tofino                    0                    0
# 197              0   Melbourne                    0                    0
# 198  San Francisco  Sacramento                    0                    0
# 199       BRASILIA       KYOTO  2022-09-04 00:00:00                    0
#
#     budget_formate  Score
# 0                0      0
# 1                0      2
# 2                0      0
# 3                0      2
# 4                0      0
# ..             ...    ...
# 195         2000.0      0
# 196              0      0
# 197              0      0
# 198              0      2
# 199         4000.0      0
#
# [200 rows x 11 columns]

# %%
df_quantite_cell = df_test[[
    'or_city', 'dst_city', 'str_date', 'end_date', 'budget'
]].shape
df_quantite_cell

# %%
quantity_cell = df_quantite_cell[0] * df_quantite_cell[1]
quantity_cell
# Out:
# 1000

# %%
score = quantite_bonne_reponse / quantity_cell * 100
score = str(score) + "%"
score
# Out:
# '13.8%'

# %% [markdown]
# Nous avons un score accuracy de 13.8%.

# %% [markdown]
# ### Optimisation

# %% [markdown]
# Nous allons maintenant ajouter les données prébuilt dans les prédictions et nous allons voir si cela permet d'améliorer notre score.

# %%
df_avec_prebuilt = df_merged[[
    "text", "or_city_x", "dst_city_x", "str_date_x", "end_date_x", "budget_x",
    "geographyV2", "money", "date_prebuilt_start", "date_prebuilt_end",
    "date_prebuilt_inconnu"
]]

# %%
df_avec_prebuilt
# Out:
#                                                   text      or_city_x  \
# 0    Three words: Alexandria to Cencun. Please book...            NaN
# 1    Hello. I'm just gonna be honest with you, here...          Busan
# 2                Need two tickets out of Buenos Aires!            NaN
# 3               I need to get to Marseille from Dallas         Dallas
# 4    Hi there, I'm looking for a trip for 5 between...            NaN
# ..                                                 ...            ...
# 195  Hello. I am a deeply tormented children’s writ...            NaN
# 196  I have a business trip coming up in Punta Cana...            NaN
# 197                                   Melbourne please            NaN
# 198  Good morning! So I just won the lottery and de...  San Francisco
# 199      BRASILIA TO KYOTO, SEPT 4. $4000 Budget GOOOO            NaN
#
#      dst_city_x str_date_x end_date_x budget_x   geographyV2   money  \
# 0           NaN        NaT        NaT      NaN           NaN     NaN
# 1     Melbourne 2022-08-24        NaT      NaN           NaN     NaN
# 2           NaN        NaT        NaT      NaN  Buenos Aires     NaN
# 3     Marseille        NaT        NaT      NaN           NaN     NaN
# 4           NaN        NaT        NaT      NaN           NaN     NaN
# ..          ...        ...        ...      ...           ...     ...
# 195         NaN        NaT        NaT      NaN   Minneapolis  2000.0
# 196  Punta Cana        NaT        NaT      NaN           NaN     NaN
# 197         NaN        NaT        NaT      NaN     Melbourne     NaN
# 198  Sacramento        NaT        NaT      NaN           NaN     NaN
# 199         NaN        NaT        NaT      NaN      BRASILIA  4000.0
#
#     date_prebuilt_start date_prebuilt_end date_prebuilt_inconnu
# 0                   NaN               NaN   2022-10-28 17:00:44
# 1                   NaN               NaN                   NaN
# 2                   NaN               NaN                   NaN
# 3                   NaN               NaN                   NaN
# 4            2022-08-25        2022-08-28                   NaN
# ..                  ...               ...                   ...
# 195          2000-01-01        2001-01-01                   NaN
# 196                 NaN               NaN                   NaN
# 197                 NaN               NaN                   NaN
# 198                 NaN               NaN                   NaN
# 199                 NaN               NaN            2022-09-04
#
# [200 rows x 11 columns]

# %% [markdown]
# En ce qui concerne les colonnes geographyV2 et data_prebuilt_inconnu, comme nous l'avions dit, nous ne savons pas si elles concernent l'origine ou la destination.
#
# Nous allons partir du faite que ce sont des destinations, en effet, il est bien plus probable que les utilisateurs demandent directement le lieu de destination plutôt que leur localisation d'origine et la date de départ de leur vol plutôt que la date de retour.

# %%
# Ramplace les valeurs de la colonne par une autre colonne lorsque celle-ci est un NaN
df_avec_prebuilt["str_date_x"].fillna(df_avec_prebuilt["date_prebuilt_start"],
                                      inplace=True)
df_avec_prebuilt["str_date_x"].fillna(
    df_avec_prebuilt["date_prebuilt_inconnu"], inplace=True)

df_avec_prebuilt["end_date_x"].fillna(df_avec_prebuilt["date_prebuilt_end"],
                                      inplace=True)
df_avec_prebuilt["budget_x"].fillna(df_avec_prebuilt["money"], inplace=True)
df_avec_prebuilt["dst_city_x"].fillna(df_avec_prebuilt["geographyV2"],
                                      inplace=True)

del df_avec_prebuilt['date_prebuilt_start']
del df_avec_prebuilt['date_prebuilt_inconnu']
del df_avec_prebuilt['date_prebuilt_end']
del df_avec_prebuilt['money']
del df_avec_prebuilt['geographyV2']
# Out:
# D:\Temp\ipykernel_11176\1465061890.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avec_prebuilt["str_date_x"].fillna(df_avec_prebuilt["date_prebuilt_start"], inplace=True)
# D:\Temp\ipykernel_11176\1465061890.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avec_prebuilt["str_date_x"].fillna(df_avec_prebuilt["date_prebuilt_inconnu"], inplace=True)
# D:\Temp\ipykernel_11176\1465061890.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avec_prebuilt["end_date_x"].fillna(df_avec_prebuilt["date_prebuilt_end"], inplace=True)
# D:\Temp\ipykernel_11176\1465061890.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avec_prebuilt["budget_x"].fillna(df_avec_prebuilt["money"], inplace=True)
# D:\Temp\ipykernel_11176\1465061890.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avec_prebuilt["dst_city_x"].fillna(df_avec_prebuilt["geographyV2"], inplace=True)

# %%
df_avec_prebuilt
# Out:
#                                                   text      or_city_x  \
# 0    Three words: Alexandria to Cencun. Please book...            NaN
# 1    Hello. I'm just gonna be honest with you, here...          Busan
# 2                Need two tickets out of Buenos Aires!            NaN
# 3               I need to get to Marseille from Dallas         Dallas
# 4    Hi there, I'm looking for a trip for 5 between...            NaN
# ..                                                 ...            ...
# 195  Hello. I am a deeply tormented children’s writ...            NaN
# 196  I have a business trip coming up in Punta Cana...            NaN
# 197                                   Melbourne please            NaN
# 198  Good morning! So I just won the lottery and de...  San Francisco
# 199      BRASILIA TO KYOTO, SEPT 4. $4000 Budget GOOOO            NaN
#
#        dst_city_x           str_date_x  end_date_x budget_x
# 0             NaN  2022-10-28 17:00:44         NaN      NaN
# 1       Melbourne  2022-08-24 00:00:00         NaN      NaN
# 2    Buenos Aires                  NaN         NaN      NaN
# 3       Marseille                  NaN         NaN      NaN
# 4             NaN           2022-08-25  2022-08-28      NaN
# ..            ...                  ...         ...      ...
# 195   Minneapolis           2000-01-01  2001-01-01   2000.0
# 196    Punta Cana                  NaN         NaN      NaN
# 197     Melbourne                  NaN         NaN      NaN
# 198    Sacramento                  NaN         NaN      NaN
# 199      BRASILIA           2022-09-04         NaN   4000.0
#
# [200 rows x 6 columns]

# %% [markdown]
# Nous pouvons maintenant relancer le scoring.

# %%
df_avec_prebuilt_all = pd.merge(df_avec_prebuilt[[
    "text", "or_city_x", "dst_city_x", "str_date_x", "end_date_x", "budget_x"
]],
                                df_test[[
                                    "text", "or_city", "dst_city",
                                    "str_date_formate", "end_date_formate",
                                    "budget_formate"
                                ]],
                                on=['text'])

df_avec_prebuilt_all.head(5)
# Out:
#                                                 text or_city_x    dst_city_x  \
# 0  Three words: Alexandria to Cencun. Please book...       NaN           NaN
# 1  Hello. I'm just gonna be honest with you, here...     Busan     Melbourne
# 2              Need two tickets out of Buenos Aires!       NaN  Buenos Aires
# 3             I need to get to Marseille from Dallas    Dallas     Marseille
# 4  Hi there, I'm looking for a trip for 5 between...       NaN           NaN
#
#             str_date_x  end_date_x budget_x       or_city   dst_city  \
# 0  2022-10-28 17:00:44         NaN      NaN    Alexandria     Cencun
# 1  2022-08-24 00:00:00         NaN      NaN         Busan  Melbourne
# 2                  NaN         NaN      NaN  Buenos Aires        NaN
# 3                  NaN         NaN      NaN        Dallas  Marseille
# 4           2022-08-25  2022-08-28      NaN        Tofino     Dallas
#
#   str_date_formate end_date_formate  budget_formate
# 0              NaT       2022-09-06             NaN
# 1       2022-10-23              NaT             NaN
# 2              NaT              NaT             NaN
# 3              NaT              NaT             NaN
# 4       2022-08-25       2022-08-28             NaN

# %%
df_avec_prebuilt_all = df_avec_prebuilt_all[[
    "or_city_x", "dst_city_x", "str_date_x", "end_date_x", "budget_x",
    "or_city", "dst_city", "str_date_formate", "end_date_formate",
    "budget_formate"
]]

# %%
list_columns_pred = [
    "or_city_x", "dst_city_x", "str_date_x", "end_date_x", "budget_x"
]
list_columns_target = [
    "or_city", "dst_city", "str_date_formate", "end_date_formate",
    "budget_formate"
]
df_avec_prebuilt_all['Score'] = 0

for i in range(len(df_test)):
    df_avec_prebuilt_all["Score"].iloc[i] = 0
    for colonne_x, colonne_y in zip(list_columns_target, list_columns_pred):
        if df_avec_prebuilt_all[colonne_y].iloc[i] != "0":
            if df_avec_prebuilt_all[colonne_y].iloc[i] == df_avec_prebuilt_all[
                    colonne_x].iloc[i]:
                df_avec_prebuilt_all["Score"].iloc[i] += 1
# Out:
# D:\Temp\ipykernel_11176\2980921366.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avec_prebuilt_all["Score"].iloc[i] = 0
# D:\Temp\ipykernel_11176\2980921366.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_avec_prebuilt_all["Score"].iloc[i] += 1

# %%
quantite_bonne_reponse = df_avec_prebuilt_all["Score"].sum()
quantite_bonne_reponse
# Out:
# 186

# %%
score = quantite_bonne_reponse / 1000 * 100
score = str(score) + "%"
score
# Out:
# '18.6%'

# %% [markdown]
# Nous avons pu améliorer le score de 4,8% en passant de 13,8% à 18,6%.

# %% [markdown]
# Nous avons terminé l'entrainement de notre modèle.
